# %% [markdown]
# # python matplotlib Tutorial-11 and 12

# %% [markdown]
# # matplotlib imshow function

# %% [markdown]
# # how to show image using matplotlib imshow function?

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread('pie_chart.png')
img
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
plt.figure(figsize=(16,9))
img=mpimg.imread('pie_chart2.png')
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(16,9))
img=mpimg.imread('pie_chart2.png')
plt.axis('off')
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(16,9))
img=mpimg.imread('pie_chart2.png')
plt.axis('off')
plt.imshow(img,cmap='Accent')
plt.colorbar()
plt.show()

# %%
single_channel=img[:,:,1]
plt.figure(figsize=(16,9))
img=mpimg.imread('pie_chart2.png')
plt.axis('off')
plt.imshow(single_channel,cmap='Accent')
plt.colorbar()
plt.show()

# %%
single_channel=img[:,:,2]
plt.figure(figsize=(16,9))
img=mpimg.imread('pie_chart2.png')
plt.axis('off')
plt.imshow(single_channel,cmap='hot')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(16,9))
img2=mpimg.imread('G:\\yogi\\3648678.jpg')
plt.imshow(img2,cmap="hot")
plt.axis('off')
plt.colorbar()
plt.show()

# %% [markdown]
# # part-13

# %%
#we using diffrent-diffrent color map

# %%
#hme hmesa color map ka use karte time single channel ko lena hota hai
single_channe_img=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread('G:\\yogi\\3648678.jpg')
plt.imshow(single_channe_img,cmap="hot")
plt.axis('off')
plt.colorbar()
plt.savefig('hot car.png')
plt.show()

# %%
#parameter of cmap

# %%
'''
'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

'''
# Out:
# "\n'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag
# ...

# %%
single_channe_img=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread('G:\\yogi\\3648678.jpg')
plt.imshow(single_channe_img,cmap="Accent")
plt.axis('off')
plt.colorbar()
plt.savefig('hot car1.png')
plt.show()

# %%
single_channe_img=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread('G:\\yogi\\3648678.jpg')
plt.imshow(single_channe_img,cmap="Blues")
plt.axis('off')
plt.colorbar()
plt.savefig('hot car1.png')
plt.show()

# %%
single_channe_img=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread('G:\\yogi\\3648678.jpg')
plt.imshow(single_channe_img,cmap="twilight_shifted")
plt.axis('off')
plt.colorbar()
plt.savefig('hot car1.png')
plt.show()

# %%
cmap='Accent,Accent_r,  Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r,Paired'
cmap_name_list=cmap.split(sep=",")
print(cmap_name_list)
# Out:
# ['Accent', 'Accent_r', '  Blues_r', ' BrBG', ' BrBG_r', ' BuGn', ' BuGn_r', ' BuPu', ' BuPu_r', ' CMRmap', ' CMRmap_r', ' Dark2', ' Dark2_r', ' GnBu', ' GnBu_r', ' Greens', ' Greens_r', ' Greys', ' Greys_r', ' OrRd', ' OrRd_r', ' Oranges', ' Oranges_r', ' PRGn', ' PRGn_r', 'Paired']

# %%
save_image_addr_name=[]
for i in range(len(cmap_name_list)):
    cmap_str=cmap_name_list[i]
    save_image_addr_name.append("G:\\csv\\_"+"_car_" +cmap_name_list[i]+".png")
    print(save_image_addr_name[i])
# Out:
# G:\csv\__car_Accent.png
# G:\csv\__car_Accent_r.png
# G:\csv\__car_ Blues.png
# G:\csv\__car_ Blues_r.png
# G:\csv\__car_ BrBG.png
# G:\csv\__car_ BrBG_r.png
# G:\csv\__car_ BuGn.png
# G:\csv\__car_ BuGn_r.png
# G:\csv\__car_ BuPu.png
# G:\csv\__car_ BuPu_r.png
# G:\csv\__car_ CMRmap.png
# G:\csv\__car_ CMRmap_r.png
# G:\csv\__car_ Dark2.png
# G:\csv\__car_ Dark2_r.png
# G:\csv\__car_ GnBu.png
# G:\csv\__car_ GnBu_r.png
# G:\csv\__car_ Greens.png
# G:\csv\__car_ Greens_r.png
# G:\csv\__car_ Greys.png
# G:\csv\__car_ Greys_r.png
# G:\csv\__car_ OrRd.png
# G:\csv\__car_ OrRd_r.png
# G:\csv\__car_ Oranges.png
# G:\csv\__car_ Oranges_r.png
# G:\csv\__car_ PRGn.png
# G:\csv\__car_ PRGn_r.png
# G:\csv\__car_Paired.png

# %%
for i in range(len(cmap_name_list)):
    cmap_name=cmap_name_list[i]
    plt.figure(figsize=(16,9))
    plt.axis('off')
    print(cmap_name)
    plt.imshow(single_channe_img,cmap=cmap_name)
    #plt.colorbar()
    #save_image_addr_name.append("G\\csv\\_"+"_car_" +cmap_name_list[i]+".png")
    plt.savefig(save_image_addr_name[i],orientation='portrate',facecolor='k')
    plt.show()
# Out:
# Accent
# Accent_r
#   Blues_r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a2fbf412ed0c> in <module>
#       4     plt.axis('off')
#       5     print(cmap_name)
# ----> 6     plt.imshow(single_channe_img,cmap=cmap_name)
#       7     #plt.colorbar()
#       8     #save_image_addr_name.append("G\\csv\\_"+"_car_" +cmap_name_list[i]+".png")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ...
