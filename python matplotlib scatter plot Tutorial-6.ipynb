# %% [markdown]
# # python matplotlib tutorial-7

# %% [markdown]
# # scatter plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style

# %%
#csv data set lete hai
df_google_playstore_data=pd.read_csv('E:\\csv files\\googleplaystore.csv')
df_google_playstore_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.set_option('display.max_columns',None)
df_google_playstore_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_google_playstore_data.shape
# Out:
# (10841, 13)

# %%
df_google_playstore_data=pd.read_csv('E:\\csv files\\googleplaystore.csv',nrows=1000)
df_google_playstore_data
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 995                                     My Talking Pet   ENTERTAINMENT
# 996                                         Funny Pics   ENTERTAINMENT
# 997                                  Funny Quotes Free   ENTERTAINMENT
# 998                          LOL Pics (Funny Pictures)   ENTERTAINMENT
# 999                                       Meme Creator   ENTERTAINMENT
#
#      Rating  Reviews                Size     Installs  Type  Price  \
# ...

# %%
df_google_playstore_data.shape
pd.set
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6405a702e568> in <module>
#       1 df_google_playstore_data.shape
# ----> 2 pd.set
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'set'

# %%
x=df_google_playstore_data['Rating']
y=df_google_playstore_data['Reviews']
z=df_google_playstore_data['Installs']

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.title('googleplay store rating and reviews',fontsize=20)
plt.xlabel('ratings',fontsize=20)
plt.ylabel('reviews',fontsize=20)
# Out:
# Text(0, 0.5, 'reviews')

# %%
'''
plt.scatter(
    x,
    y,
    s=None,
    c=None,
    marker=None,
    cmap=None,
    norm=None,
    vmin=None,
    vmax=None,
    alpha=None,
    linewidths=None,
    verts=<deprecated parameter>,
    edgecolors=None,
    *,
    plotnonfinite=False,
    data=None,
    **kwargs,
)
Docstring:
A scatter plot of *y* vs. *x* with varying marker size and/or color.

Parameters
----------
x, y : scalar or array-like, shape (n, )
    The data positions.

s : scalar or array-like, shape (n, ), optional
    The marker size in points**2.
    Default is ``rcParams['lines.markersize'] ** 2``.

c : array-like or list of colors or color, optional
    The marker colors. Possible values:

    - A scalar or sequence of n numbers to be mapped to colors using
      *cmap* and *norm*.
    - A 2-D array in which the rows are RGB or RGBA.
    - A sequence of colors of length n.
    - A single color format string.

    Note that *c* should not be a single numeric RGB or RGBA sequence
    because that is indistinguishable from an array of values to be
    colormapped. If you want to specify the same RGB or RGBA value for
    all points, use a 2-D array with a single row.  Otherwise, value-
    matching will have precedence in case of a size matching with *x*
    and *y*.

    If you wish to specify a single color for all points
    prefer the *color* keyword argument.

    Defaults to `None`. In that case the marker color is determined
    by the value of *color*, *facecolor* or *facecolors*. In case
    those are not specified or `None`, the marker color is determined
    by the next color of the ``Axes``' current "shape and fill" color
    cycle. This cycle defaults to :rc:`axes.prop_cycle`.

marker : `~matplotlib.markers.MarkerStyle`, optional
    The marker style. *marker* can be either an instance of the class
    or the text shorthand for a particular marker.
    Defaults to ``None``, in which case it takes the value of
    :rc:`scatter.marker` = 'o'.
    See `~matplotlib.markers` for more information about marker styles.

cmap : `~matplotlib.colors.Colormap`, optional, default: None
    A `.Colormap` instance or registered colormap name. *cmap* is only
    used if *c* is an array of floats. If ``None``, defaults to rc
    ``image.cmap``.

norm : `~matplotlib.colors.Normalize`, optional, default: None
    A `.Normalize` instance is used to scale luminance data to 0, 1.
    *norm* is only used if *c* is an array of floats. If *None*, use
    the default `.colors.Normalize`.

vmin, vmax : scalar, optional, default: None
    *vmin* and *vmax* are used in conjunction with *norm* to normalize
    luminance data. If None, the respective min and max of the color
    array is used. *vmin* and *vmax* are ignored if you pass a *norm*
    instance.

alpha : scalar, optional, default: None
    The alpha blending value, between 0 (transparent) and 1 (opaque).

linewidths : scalar or array-like, optional, default: None
    The linewidth of the marker edges. Note: The default *edgecolors*
    is 'face'. You may want to change this as well.
    If *None*, defaults to :rc:`lines.linewidth`.

edgecolors : {'face', 'none', *None*} or color or sequence of color, optional.
    The edge color of the marker. Possible values:

    - 'face': The edge color will always be the same as the face color.
    - 'none': No patch boundary will be drawn.
    - A Matplotlib color or sequence of color.

    Defaults to ``None``, in which case it takes the value of
    :rc:`scatter.edgecolors` = 'face'
'''

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,color='g',edgecolor='y',alpha=0.6,marker=".")
plt.title('googleplay store rating and reviews',fontsize=20)
plt.xlabel('ratings',fontsize=12)
plt.ylabel('reviews',fontsize=12)
# Out:
# Text(0, 0.5, 'reviews')

# %%
from matplotlib import style

# %%
style.use('ggplot')
plt.figure(figsize=(16,9))
plt.scatter(x,y,color='g',edgecolor='y',alpha=0.6,s=100,linewidth=3,marker="*")
plt.title('googleplay store rating and reviews',fontsize=20)
plt.xlabel('ratings',fontsize=12)
plt.ylabel('reviews',fontsize=12)
#plt.grid(linestyle='--',color='w',linewidth=1)
# Out:
# Text(0, 0.5, 'reviews')

# %%
#2scatter plot
df_google_playstore_data=pd.read_csv('E:\\csv files\\googleplaystore.csv',nrows=4000)
df_google_playstore_data
x=df_google_playstore_data['Rating']
y=df_google_playstore_data['Reviews']
z=df_google_playstore_data['Installs']
style.use('ggplot')
plt.figure(figsize=(16,9))
plt.scatter(x,y,color='g',edgecolor='y',alpha=0.6,s=100,linewidth=4,marker="*",label='reviews')
plt.scatter(x,z,color='y',edgecolor='m',alpha=0.6,s=30,linewidth=3,marker="o",label='install')
plt.scatter(x,df_google_playstore_data['Price'],color='w',edgecolor='g',s=20,linewidth=2,marker=".",alpha=0.4,label='price')
plt.legend()
plt.title('googleplay store rating and reviews',fontsize=20)
plt.xlabel('ratings',fontsize=12)
plt.ylabel('reviews,install and prices',fontsize=12)
plt.show()
